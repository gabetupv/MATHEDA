# %% [markdown]
# # ENDTERM PROJECT - Game Recommendations on Steam EDA <hr style="border:5px solid #126782"></hr>

# %% [markdown]
# **Name:** Gabriel Blaise Pusta <br>
# **Course:** BSCPE2A

# %% [markdown]
# ## **I - CLEANING**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading Dataset

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\MATHEDA Pusta\ENDTERM ACTIVITY\raw\steam-trends2023.csv", 
                 delimiter = ",")
df.head(8)
# Out:
#    App ID                             Title  Reviews Total  \
# 0     730  Counter-Strike: Global Offensive        7382695
# 1  578080               PUBG: BATTLEGROUNDS        2201296
# 2     570                            Dota 2        2017009
# 3  271590                Grand Theft Auto V        1322782
# 4  359550   Tom Clancy's Rainbow Six® Siege         978762
# 5  105600                          Terraria         927752
# 6    4000                       Garry's Mod         841853
# 7  252490                              Rust         775223
#
#   Reviews Score Fancy Release Date  Reviews D7  Reviews D30  Reviews D90  \
# 0                 88%   2012-08-21         NaN          NaN          NaN
# 1                 57%   2017-12-21         NaN          NaN          NaN
# 2                 82%   2013-07-09         NaN          NaN          NaN
# 3              89,85%   2015-04-13         NaN          NaN          NaN
# 4                 86%   2015-12-01         NaN          NaN          NaN
# 5                 97%   2011-05-16         NaN          NaN          NaN
# 6                 96%   2006-11-29         NaN          NaN          NaN
# 7                 87%   2018-02-08         NaN          NaN          NaN
#
#   Launch Price                                               Tags  name_slug  \
# 0       $14,99  FPS, Shooter, Multiplayer, Competitive, Action...        NaN
# 1       $29,99  Survival, Shooter, Battle Royale, Multiplayer,...        NaN
# 2       $29,99  Free to Play, MOBA, Multiplayer, Strategy, eSp...        NaN
# 3       $29,99  Open World, Action, Multiplayer, Crime, Automo...        NaN
# 4       $59,99  FPS, PvP, eSports, Shooter, Multiplayer, Tacti...        NaN
# 5        $9,99  Open World Survival Craft, Sandbox, Survival, ...        NaN
# 6        $9,99  Sandbox, Multiplayer, Funny, Moddable, Buildin...        NaN
# 7       $39,99  Survival, Crafting, Multiplayer, Open World, O...        NaN
#
#   Revenue Estimated                                      Modified Tags  \
# 0   $110 666 598,05  FPS_, Shooter_, Multiplayer_, Competitive_, Ac...
# 1    $66 016 867,04  Survival_, Shooter_, Battle Royale_, Multiplay...
# 2    $60 490 099,91  Free to Play_, MOBA_, Multiplayer_, Strategy_,...
# 3    $39 670 232,18  Open World_, Action_, Multiplayer_, Crime_, Au...
# 4    $58 715 932,38  FPS_, PvP_, eSports_, Shooter_, Multiplayer_, ...
# 5     $9 268 242,48  Open World Survival Craft_, Sandbox_, Survival...
# 6     $8 410 111,47  Sandbox_, Multiplayer_, Funny_, Moddable_, Bui...
# 7    $31 001 167,77  Survival_, Crafting_, Multiplayer_, Open World...
#
#                                   Steam Page
# 0     https://store.steampowered.com/app/730
# 1  https://store.steampowered.com/app/578080
# 2     https://store.steampowered.com/app/570
# 3  https://store.steampowered.com/app/271590
# 4  https://store.steampowered.com/app/359550
# 5  https://store.steampowered.com/app/105600
# 6    https://store.steampowered.com/app/4000
# 7  https://store.steampowered.com/app/252490

# %% [markdown]
# ### Cleaning the Dataset

# %%
print(df.isna().sum()) #Check for NAN values
# Out:
# App ID                     0
# Title                      0
# Reviews Total              0
# Reviews Score Fancy        0
# Release Date               0
# Reviews D7             65111
# Reviews D30            65111
# Reviews D90            65111
# Launch Price               0
# Tags                       0
# name_slug              65111
# Revenue Estimated          0
# Modified Tags              0
# Steam Page                 0
# dtype: int64

# %%
df = df[['App ID', 'Title', 'Reviews Total', 'Reviews Score Fancy',
         'Release Date', 'Launch Price', 'Tags', 'Revenue Estimated', 'Modified Tags']]

# converts to time format
df['Release Date'] = pd.to_datetime(df['Release Date'], errors='coerce')

df['Launch Price'] = df['Launch Price'].str.replace(r'[^\d,]', '', regex=True) #removes $
df['Launch Price'] = df['Launch Price'].astype(str).str.replace(',', '.', regex=False) #replaces , to .
df['Launch Price'] = df['Launch Price'].astype(float)

df['Revenue Estimated'] = df['Revenue Estimated'].str.replace(r'[^\d,]', '', regex=True) #removes $
df['Revenue Estimated'] = df['Revenue Estimated'].astype(str).str.replace(',', '.', regex=False) #replaces , to .
df['Revenue Estimated'] = df['Revenue Estimated'].astype(float)

df['Reviews Total'] = pd.to_numeric(df['Reviews Total'], errors='coerce')

# %%
df.to_csv(r"C:\Users\User\Desktop\MATHEDA Pusta\ENDTERM ACTIVITY\raw\steam-trends2023-cleaned.csv",index=False)

# %%
df.head(10)
# Out:
#    App ID                             Title  Reviews Total  \
# 0     730  Counter-Strike: Global Offensive        7382695
# 1  578080               PUBG: BATTLEGROUNDS        2201296
# 2     570                            Dota 2        2017009
# 3  271590                Grand Theft Auto V        1322782
# 4  359550   Tom Clancy's Rainbow Six® Siege         978762
# 5  105600                          Terraria         927752
# 6    4000                       Garry's Mod         841853
# 7  252490                              Rust         775223
# 8  292030         The Witcher® 3: Wild Hunt         662523
# 9  945360                          Among Us         585788
#
#   Reviews Score Fancy Release Date  Launch Price  \
# 0                 88%   2012-08-21         14.99
# 1                 57%   2017-12-21         29.99
# 2                 82%   2013-07-09         29.99
# 3              89,85%   2015-04-13         29.99
# 4                 86%   2015-12-01         59.99
# 5                 97%   2011-05-16          9.99
# 6                 96%   2006-11-29          9.99
# 7                 87%   2018-02-08         39.99
# 8                 96%   2015-05-18         39.99
# 9                 92%   2018-11-16          4.99
#
#                                                 Tags  Revenue Estimated  \
# 0  FPS, Shooter, Multiplayer, Competitive, Action...       1.106666e+08
# 1  Survival, Shooter, Battle Royale, Multiplayer,...       6.601687e+07
# 2  Free to Play, MOBA, Multiplayer, Strategy, eSp...       6.049010e+07
# 3  Open World, Action, Multiplayer, Crime, Automo...       3.967023e+07
# 4  FPS, PvP, eSports, Shooter, Multiplayer, Tacti...       5.871593e+07
# 5  Open World Survival Craft, Sandbox, Survival, ...       9.268242e+06
# 6  Sandbox, Multiplayer, Funny, Moddable, Buildin...       8.410111e+06
# 7  Survival, Crafting, Multiplayer, Open World, O...       3.100117e+07
# 8  Open World, RPG, Story Rich, Atmospheric, Matu...       2.649429e+07
# 9  Multiplayer, Online Co Op, Social Deduction, S...       2.923082e+06
#
#                                        Modified Tags
# 0  FPS_, Shooter_, Multiplayer_, Competitive_, Ac...
# 1  Survival_, Shooter_, Battle Royale_, Multiplay...
# 2  Free to Play_, MOBA_, Multiplayer_, Strategy_,...
# 3  Open World_, Action_, Multiplayer_, Crime_, Au...
# 4  FPS_, PvP_, eSports_, Shooter_, Multiplayer_, ...
# 5  Open World Survival Craft_, Sandbox_, Survival...
# 6  Sandbox_, Multiplayer_, Funny_, Moddable_, Bui...
# 7  Survival_, Crafting_, Multiplayer_, Open World...
# 8  Open World_, RPG_, Story Rich_, Atmospheric_, ...
# 9  Multiplayer_, Online Co Op_, Social Deduction_...

# %%
df_top_games = df.nlargest(10, 'Reviews Total')
table = df_top_games[['Title', 'Reviews Total']]
print(table)
# Out:
#                               Title  Reviews Total
# 0  Counter-Strike: Global Offensive        7382695
# 1               PUBG: BATTLEGROUNDS        2201296
# 2                            Dota 2        2017009
# 3                Grand Theft Auto V        1322782
# 4   Tom Clancy's Rainbow Six® Siege         978762
# 5                          Terraria         927752
# 6                       Garry's Mod         841853
# 7                              Rust         775223
# 8         The Witcher® 3: Wild Hunt         662523
# 9                          Among Us         585788

# %%
top_games = df.nlargest(10, 'Reviews Total')  # Get top 10 reviewed games

plt.figure(figsize=(12, 6))
sns.barplot(y=top_games['Title'], x=top_games['Reviews Total'], palette="Blues_r")
plt.xlabel("Total Reviews")
plt.ylabel("Game Title")
plt.title("Top 10 Most Reviewed Games on Steam")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\1853518790.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_games['Title'], x=top_games['Reviews Total'], palette="Blues_r")

# %%
df_top_revenue = df.nlargest(10, 'Revenue Estimated')
table = df_top_revenue[['Title', 'Revenue Estimated', 'Reviews Total']]
print(table)
# Out:
#                                Title  Revenue Estimated  Reviews Total
# 0   Counter-Strike: Global Offensive       1.106666e+08        7382695
# 1                PUBG: BATTLEGROUNDS       6.601687e+07        2201296
# 2                             Dota 2       6.049010e+07        2017009
# 4    Tom Clancy's Rainbow Six® Siege       5.871593e+07         978762
# 3                 Grand Theft Auto V       3.967023e+07        1322782
# 12                    Cyberpunk 2077       3.293475e+07         549004
# 13                        ELDEN RING       3.119624e+07         520024
# 7                               Rust       3.100117e+07         775223
# 8          The Witcher® 3: Wild Hunt       2.649429e+07         662523
# 21             Red Dead Redemption 2       2.369227e+07         394937

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar chart for revenue
sns.barplot(x='Title', y='Revenue Estimated', data=df_top_revenue, ax=ax1, color='#331B3F', label='Revenue')
ax1.set_ylabel("Revenue Estimated ($)", color='#331B3F')
ax1.tick_params(axis='y', labelcolor='#331B3F')
ax1.set_xticklabels(df_top_revenue['Title'], rotation=45, ha="right")

# Create a second y-axis for reviews
ax2 = ax1.twinx()
sns.lineplot(x='Title', y='Reviews Total', data=df_top_revenue, ax=ax2, color='#ACC7B4', marker="o", label='Reviews')
ax2.set_ylabel("Total Reviews", color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Title and labels
plt.title("Top 10 Games by Revenue and Their Reviews")
fig.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\737140156.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df_top_revenue['Title'], rotation=45, ha="right")

# %%
df['Release Year'] = pd.to_datetime(df['Release Date'], errors='coerce').dt.year
yearly_counts = df['Release Year'].value_counts().sort_index()
print(yearly_counts)
# Out:
# Release Year
# 1970       74
# 1983        2
# 1984        3
# 1985        4
# 1986        6
# 1987        6
# 1988       15
# 1989       15
# 1990       22
# 1991       15
# 1992       21
# 1993       30
# 1994       40
# 1995       36
# 1996       43
# 1997       50
# 1998       57
# 1999       53
# 2000       50
# 2001       61
# 2002       51
# 2003       85
# 2004       74
# 2005       95
# 2006      141
# 2007      154
# 2008      190
# 2009      265
# 2010      296
# 2011      339
# 2012      403
# 2013      518
# 2014     1228
# 2015     2239
# 2016     3767
# 2017     5413
# 2018     7051
# 2019     6771
# 2020     8236
# 2021     9743
# 2022    10641
# 2023     6806
# 2024        2
# Name: count, dtype: int64

# %%
df['Release Year'] = pd.to_datetime(df['Release Date'], errors='coerce').dt.year
yearly_counts = df['Release Year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x=yearly_counts.index, y=yearly_counts.values, marker="o")
plt.xlabel("Year")
plt.ylabel("Number of Games Released")
plt.title("Number of Games Released Per Year")
plt.show()

# %%
all_tags = ','.join(df['Modified Tags'].dropna()).replace('_', '').split(',')

# Count occurrences
tag_counts = Counter(all_tags)
tag_df = pd.DataFrame(tag_counts.items(), columns=['Tag', 'Count']).sort_values(by='Count', ascending=False).head(10)

# Display table
print(tag_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       1 all_tags = ','.join(df['Modified Tags'].dropna()).replace('_', '').split(',')
#       3 # Count occurrences
# ----> 4 tag_counts = Counter(all_tags)
#       5 tag_df = pd.DataFrame(tag_counts.items(), columns=['Tag', 'Count']).sort_values(by='Count', ascending=False).head(10)
#       7 # Display table
#
# NameError: name 'Counter' is not defined

# %%
from collections import Counter

# Flatten all tags into a single list
all_tags = ','.join(df['Modified Tags'].dropna()).replace('_', '').split(',')

# Count occurrences
tag_counts = Counter(all_tags)
tag_df = pd.DataFrame(tag_counts.items(), columns=['Tag', 'Count']).sort_values(by='Count', ascending=False).head(10)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(y=tag_df['Tag'], x=tag_df['Count'], palette="viridis")
plt.xlabel("Count")
plt.ylabel("Game Tag")
plt.title("Top 10 Most Frequent Game Tags on Steam")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21076\4103350158.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=tag_df['Tag'], x=tag_df['Count'], palette="viridis")

# %%
top_revenue_games = df.nlargest(10, 'Revenue Estimated')

# Plot pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_revenue_games['Revenue Estimated'], labels=top_revenue_games['Title'], autopct='%1.1f%%', startangle=140)
plt.title("Top 10 Games by Revenue Distribution")
plt.axis('equal')  # Equal aspect ratio ensures that pie is a circle.
plt.show()

# %%
revenue_singleplayer_games = df[df['Modified Tags'].str.contains('Singleplayer', na=False, case=False)]
top_10revenue_singleplayer = revenue_singleplayer_games.nlargest(10, 'Revenue Estimated')
print(top_10revenue_singleplayer[['Title', 'Revenue Estimated']])
# Out:
#                                 Title  Revenue Estimated
# 3                  Grand Theft Auto V        39670232.18
# 12                     Cyberpunk 2077        32934749.96
# 13                         ELDEN RING        31196239.76
# 8           The Witcher® 3: Wild Hunt        26494294.77
# 21              Red Dead Redemption 2        23692270.63
# 34  Call of Duty®: Modern Warfare® II        16173289.20
# 15              ARK: Survival Evolved        14698069.01
# 36                    DARK SOULS™ III        13713534.03
# 41                       No Man's Sky        12398493.24
# 43                          Fallout 4        12106581.90

# %%
reviews_singleplayer_games = df[df['Modified Tags'].str.contains('Singleplayer', na=False, case=False)]
top_10reviews_singleplayer = reviews_singleplayer_games.nlargest(10, 'Reviews Total')
print(top_10reviews_singleplayer[['Title', 'Reviews Total']])
# Out:
#                         Title  Reviews Total
# 3          Grand Theft Auto V        1322782
# 5                    Terraria         927752
# 6                 Garry's Mod         841853
# 8   The Witcher® 3: Wild Hunt         662523
# 10              Left 4 Dead 2         564441
# 12             Cyberpunk 2077         549004
# 13                 ELDEN RING         520024
# 14             Stardew Valley         495433
# 15      ARK: Survival Evolved         490099
# 19                 The Forest         413144

# %%
plt.figure(figsize=(12, 6))
sns.barplot(y=top_10revenue_singleplayer['Title'], x=top_10revenue_singleplayer['Revenue Estimated'], palette="magma")
plt.xlabel("Revenue Estimated (in USD)")
plt.ylabel("Game Title")
plt.title("Top 10 Singleplayer Games by Revenue")# Invert to have the highest revenue at the top
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\3889344283.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_10revenue_singleplayer['Title'], x=top_10revenue_singleplayer['Revenue Estimated'], palette="magma")

# %%
plt.figure(figsize=(12, 6))
sns.barplot(y=top_10reviews_singleplayer['Title'], x=top_10reviews_singleplayer['Reviews Total'], palette="magma")
plt.xlabel("Reviews Total")
plt.ylabel("Game Title")
plt.title("Top 10 Singleplayer Games by Reviews")# Invert to have the highest revenue at the top
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4500\3093809235.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_10reviews_singleplayer['Title'], x=top_10reviews_singleplayer['Reviews Total'], palette="magma")

# %%
revenue_indie_games = df[df['Modified Tags'].str.contains('indie', na=False, case=False)]
top_10revenue_indie = revenue_indie_games.nlargest(10, 'Revenue Estimated')
print(top_10revenue_indie[['Title', 'Revenue Estimated', 'Reviews Total']])
# Out:
#                            Title  Revenue Estimated  Reviews Total
# 7                           Rust        31001167.77         775223
# 15         ARK: Survival Evolved        14698069.01         490099
# 25                          DayZ        13215137.65         293735
# 41                  No Man's Sky        12398493.24         206676
# 17        Euro Truck Simulator 2         9664045.56         483444
# 5                       Terraria         9268242.48         927752
# 6                    Garry's Mod         8410111.47         841853
# 19                    The Forest         8258748.56         413144
# 22  Fall Guys: Ultimate Knockout         7787924.09         389591
# 14                Stardew Valley         7426540.67         495433
